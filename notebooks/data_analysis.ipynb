# %% [markdown]
# # GoldSense AI — Data Analysis
#
# Interactive exploration of the gold dataset. The dataset is produced by `backend/scripts/download_data.py`
# into `backend/data/raw/gold_daily.csv` (2,000 real daily rows, 2018-09-28 → 2026-09-11,
# Yahoo Finance `GC=F` plus silver, crude oil, S&P 500 and USD index columns).
#
# ## Load the data
# ```python
# import pandas as pd
# df = pd.read_csv("../backend/data/raw/gold_daily.csv", parse_dates=["Date"], index_col="Date")
# df.info(); df.describe()
# ```
#
# ## Typical exploration
# - Plot close price over time and log returns
# - Distribution / histogram of daily returns
# - Correlation heatmap across gold, silver, crude oil, S&P 500 and USD index
